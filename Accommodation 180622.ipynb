# %% [markdown]
# <a href="https://colab.research.google.com/github/Niamh2602/geocoding-property-price-register/blob/master/Accommodation%20180622.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
import io
import pandas as pd
import folium
import gc


data = files.upload()
# Out:
#      <input type="file" id="files-97a5f5d5-0dd8-44d5-a6cf-79e09c739c21" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-97a5f5d5-0dd8-44d5-a6cf-79e09c739c21">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Accommodation_Tags.csv to Accommodation_Tags.csv

# %%
Accommodation = pd.read_csv('Accommodation_Tags.csv', header = 0, index_col= None)

# %%
Accommodation.head()
# Out:
#                                Name  \
# 0                      Bramble Rock
# 1                     The Davenport
# 2                    Townsend House
# 3                      River's Edge
# 4  Amber Springs Hotel & Health Spa
#
#                                             Url         Telephone  Longitude  \
# 0                    http://www.bramblerock.com   +353(0)40445075  -6.291733
# 1  http://www.instagram.com/thedavenportdublin/   +353(0)16073500  -6.250031
# 2       http://www.townsendhouse-guesthouse.com  +353(0)579121276  -7.909500
# 3                      http://www.riversedge.ie          3.54E+11  -9.783882
# 4                  https://www.ambersprings.ie/  +353(0)539484000  -6.290339
#
#     Latitude AddressRegion AddressLocality       AddressCountry  \
# 0  53.009756       Wicklow     Glendalough  Republic of Ireland
# 1  53.341665        Dublin     Dublin City  Republic of Ireland
# 2  53.098816        Offaly            Birr  Republic of Ireland
# ...

# %%
Accommodation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2773 entries, 0 to 2772
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  2773 non-null   object
#  1   Url                   2591 non-null   object
#  2   Telephone             2768 non-null   object
#  3   Longitude             2773 non-null   float64
#  4   Latitude              2773 non-null   float64
#  5   AddressRegion         2773 non-null   object
#  6   AddressLocality       2631 non-null   object
#  7   AddressCountry        2773 non-null   object
#  8   Original Tags         2773 non-null   object
#  9   Covid Safety Charter  2773 non-null   object
#  10  Tags                  2773 non-null   object
# dtypes: float64(2), object(9)
# memory usage: 238.4+ KB

# %%
Accommodation.isnull().sum()
# Out:
# Name                      0
# Url                     182
# Telephone                 5
# Longitude                 0
# Latitude                  0
# AddressRegion             0
# AddressLocality         142
# AddressCountry            0
# Original Tags             0
# Covid Safety Charter      0
# Tags                      0
# dtype: int64

# %%
Accommodation.columns = Accommodation.columns.str.replace("AddressRegion" , "County")
Accommodation.head()
# Out:
#                                Name  \
# 0                      Bramble Rock
# 1                     The Davenport
# 2                    Townsend House
# 3                      River's Edge
# 4  Amber Springs Hotel & Health Spa
#
#                                             Url         Telephone  Longitude  \
# 0                    http://www.bramblerock.com   +353(0)40445075  -6.291733
# 1  http://www.instagram.com/thedavenportdublin/   +353(0)16073500  -6.250031
# 2       http://www.townsendhouse-guesthouse.com  +353(0)579121276  -7.909500
# 3                      http://www.riversedge.ie          3.54E+11  -9.783882
# 4                  https://www.ambersprings.ie/  +353(0)539484000  -6.290339
#
#     Latitude   County AddressLocality       AddressCountry  \
# 0  53.009756  Wicklow     Glendalough  Republic of Ireland
# 1  53.341665   Dublin     Dublin City  Republic of Ireland
# 2  53.098816   Offaly            Birr  Republic of Ireland
# ...

# %%
Accommodation.drop(['Url', 'Telephone','AddressLocality', 'AddressCountry'], axis=1)
Ireland = Accommodation.drop(['Url', 'Telephone','AddressLocality', 'AddressCountry'], axis=1)
print(Ireland)
# Out:
#                                   Name  Longitude   Latitude    County  \
# 0                         Bramble Rock  -6.291733  53.009756   Wicklow
# 1                        The Davenport  -6.250031  53.341665    Dublin
# 2                       Townsend House  -7.909500  53.098816    Offaly
# 3                         River's Edge  -9.783882  52.106485     Kerry
# 4     Amber Springs Hotel & Health Spa  -6.290339  52.668124   Wexford
# ...                                ...        ...        ...       ...
# 2768                   The Savoy Hotel  -8.629061  52.663152  Limerick
# 2769                  Dunmanus Cottage  -9.542522  51.602650      Cork
# 2770           Travelodge Cork Airport  -8.470095  51.872450      Cork
# 2771             Victoria Towers Hotel  -9.047777  53.273056    Galway
# 2772                 The Botanical B&B  -9.568428  51.777403      Cork
#
#                                           Original Tags  Covid Safety Charter  \
# ...
